# %%
import os
import ast
from config import methods_path, applications_path, problems_path, ignore_list

def is_legal_node_name(node, level, legal_node_names):
    # Check if the node is in the legal node names for the given level
    if level in legal_node_names:
        return node in legal_node_names[level]
    
    return False

def load_legal_names():
    legal_node_names = {}

    # Read the legal node names from the file
    with open("legal_node_names.txt", "r") as file:
        for line in file:
            line = line.strip()
            if line:
                level, names = line.split(":")
                level = int(level)
                names = [name.strip() for name in names.split(",")]
                legal_node_names[level] = names
    
    return legal_node_names

class pysearch:
    def __init__(self, methods_path, app_path, prob_path):
        """
        search earch repository in given path, extract the
        first line.

        Parameters
        ----------------
        method_path : str
            the folder that contains inference methods in CoFI
        app_path : str
            the folder that contains applications in espresso
        prob_path : str
            the folder that contains example problems in CoFI
            examples
        """
        self._method_path = methods_path
        self._app_path = app_path
        self._prob_path = prob_path
        self._methods = []
        self._apps = []
        self._problems = []
        self._legal_names = load_legal_names()

    def mds(self):
        return self._methods
    
    def aps(self):
        return self._apps
    
    
    def _search(self):
              

        def parse(file_path):
            
            def print_illegal_node_names(illegal_nodes):
                if illegal_nodes:
                    print(f"Illegal node name(s) encountered in {file_path}:")
                    for level, node_name in illegal_nodes:
                        print(f"Level {level}: {node_name}")
                        
            res = []
            line_number = 0
            with open(file_path) as file:
                while True:
                    line_number += 1
                    line = file.readline()
                    if line:
                        if line[0:11] == "# Method : ":
                            method_name = line.strip('\n')[11:]
                            method_tree = file.readline().strip('\n')[2:].split(" -> ")
                            method_description = file.readline().strip('\n')[15:]
                            illegal_nodes = [(i + 1, node) for i, node in enumerate(method_tree) if not is_legal_node_name(node, i + 1, self._legal_names)]
                            if illegal_nodes:
                                print_illegal_node_names(illegal_nodes)
                                raise ValueError(f"Illegal node name(s) encountered in method_tree at line {line_number} in file {file_path}")
                            method = Method(method_name, file_path, method_tree, method_description)   
                            self._methods.append(method)
                        if line[0:16] == "# Application : ":
                            app_name = line.strip('\n')[16:]
                            app_tree = file.readline().strip('\n')[2:].split(" -> ")
                            app_des = file.readline().strip('\n')[15:]
                            self._apps.append(App(app_name, file_path, app_tree, app_des))
                             
                            for app in self._apps:
                                print(app.tree())
                    else:
                        break


        for _, _, files in os.walk(self._method_path):
            for i in files:
                parse(self._method_path + '/' + i)

        for root, dirs, files in os.walk(self._app_path):
            if root == self._app_path:
                for dirr in dirs:
                    parse(self._app_path + '/' + dirr + '/' + dirr + '.py')
                    
    def search_examples(self, ignore):
        for root, _, files in os.walk(self._prob_path):
            for file_name in files:
                if file_name.endswith(".py"):
                    if file_name not in ignore:
                        file_path = os.path.join(root, file_name)
                        description = self.parse_description(file_path)
                        self._problems.append(Example(file_name, file_path, description))

    def parse_description(self, file_path):
        with open(file_path) as file:
            content = file.read()

        tree = ast.parse(content)
        docstrings = ast.get_docstring(tree)
        return docstrings if docstrings else ""

    def problems(self):
        return self._problems
        
class Method:
    def __init__(self, name, path, tree, des):
        """
        A single Method defination.

        Parameters
        -----------
        name : str
            method name
        path : str
            method file path
        tree : list
            tree path of the method
        """
        self._name = name
        self._path = path
        self._tree = tree
        self._des = des
    
    def name(self):
        return self._name
    
    def path(self):
        return self._path
    
    def tree(self):
        return self._tree
    
    def des(self):
        return self._des
    
class App:
    def __init__(self, name, path, tree, des):
        """
        A single Method defination.

        Parameters
        -----------
        name : str
            method name
        path : str
            method file path
        tree : list
            tree path of the method
        """
        self._name = name
        self._path = path
        self._tree = tree
        self._des = des
    
    def name(self):
        return self._name
    
    def path(self):
        return self._path
    
    def tree(self):
        return self._tree
    
    def des(self):
        return self._des
            

class Example:
    def __init__(self, name, path, description):
        self._name = name
        self._path = path
        self._description = description
        self._tree_path = ""

    def name(self):
        return self._name

    def path(self):
        return self._path

    def description(self):
        return self._description

    def tree_path(self):
        return self._tree_path

    def set_tree_path(self, tree_path):
        self._tree_path = tree_path


    
class TreeNode:
    def __init__(self, name):
        self.name = name
        self.children = []
        self.examples = []
        self.parent = None

    def add_child(self, child):
        self.children.append(child)
        child.parent = self

    def add_example(self, example):
        self.examples.append(example)

    def traverse(self):
        yield self
        for child in self.children:
            yield from child.traverse()      


def print_tree(node, indent=""):
    if type(node.name) == tuple:
        example = node.name
        print(indent + " - Name: {}".format(example[0]))
        print(indent + " - Path: {}".format(example[1]))
        print(indent + " - Description: {}".format(example[2]))
        print()
        print()
    else:
        print(indent + node.name)
    for child in node.children:
        print_tree(child, indent + "  ")


def build_tree_from_lists(tree_lists):
    root = None
    node_dict = {}

    for tree_list in tree_lists:
        parent_name = tree_list[0]

        if parent_name not in node_dict:
            parent_node = TreeNode(parent_name)
            node_dict[parent_name] = parent_node

            if root is None:
                root = parent_node
        else:
            parent_node = node_dict[parent_name]

        for node_name in tree_list[1:]:
            if node_name not in node_dict:
                node = TreeNode(node_name)
                node_dict[node_name] = node
            else:
                node = node_dict[node_name]

            # Check if the node already exists as a child
            existing_child = next((child for child in parent_node.children if child.name == node_name), None)
            if existing_child:
                parent_node = existing_child
            else:
                parent_node.add_child(node)
                parent_node = node

    return root

def add_examples_to_tree(root_node, example_objects, current_path=""):
    for example in example_objects:
        description = example.description().lower()  # Convert to lowercase
        added = False

        for node in root_node.traverse():
            node_name_lower = node.name.lower()
            if node_name_lower in description or node_name_lower + 's' in description:
                # Construct the tree path by including the root node at the start
                path_to_example = root_node.name + " -> " + current_path + " -> " + example.name()
                example.set_tree_path(path_to_example)

                # Add the example to the node
                node.add_example(example)

                added = True
                break  # Exit the inner loop after finding a match

        if not added:
            # If no matching node is found, add the example to the root node
            path_to_example = root_node.name + " -> " + example.name()
            example.set_tree_path(path_to_example)
            root_node.add_example(example)

    for child in root_node.children:
        add_examples_to_tree(child, example_objects, current_path=root_node.name)

    return root_node



def get_example_tree_paths(root_node):
    example_paths = []

    def traverse(node, current_path=""):
        if node.examples:
            for example in node.examples:
                example_path = current_path + " -> " + example.name()
                example_paths.append((example.name(), example.path(), example.description(), example_path))

        for child in node.children:
            traverse(child, current_path=current_path + " -> " + child.name)

    traverse(root_node)
    return example_paths

def print_tree(root_node, indent=''):
    print(f"{indent}{root_node.name}")
    for child in root_node.children:
        print_tree(child, indent + '  ')
    if root_node.examples:
        for example in root_node.examples:
            print(f"{indent}  Example: {example.name()} ({example.path()})")
            print(f"{indent}    Description: {example.description()}")

            
    
if __name__ == "__main__":
    tree_lists = []

    p = pysearch(methods_path, applications_path, problems_path)
    p._search()
    p.search_examples(ignore_list)
    problems = p.problems()

    for method in p._methods:
        tree_lists.append(method.tree())

    root_node = build_tree_from_lists(tree_lists)
    root_node = add_examples_to_tree(root_node, problems)
    
    example_paths = get_example_tree_paths(root_node)
    for example_path in example_paths:
        print("Example Tree Path:", example_path[3])
        print()

    print_tree(root_node)
# Out:
# ['37 Earth Sciences', '3706 Geophysics', '370609 Seismology And Seismic Exploration', 'Fast Marching Method']
# ['37 Earth Sciences', '3706 Geophysics', '370609 Seismology And Seismic Exploration', 'Fast Marching Method']
# ['37 Earth Sciences', '3706 Geophysics', '370606 Gravimetrics', '3D gravity']
# ['37 Earth Sciences', '3706 Geophysics', '370609 Seismology And Seismic Exploration', 'Fast Marching Method']
# ['37 Earth Sciences', '3706 Geophysics', '370606 Gravimetrics', '3D gravity']
# ['37 Earth Sciences', '3706 Geophysics', '370602 Electrical And Electromanetic Methods In Geophysics', 'Magnetotelluric', 'Magnetotelluric_1D']
# ['37 Earth Sciences', '3706 Geophysics', '370609 Seismology And Seismic Exploration', 'Fast Marching Method']
# ['37 Earth Sciences', '3706 Geophysics', '370606 Gravimetrics', '3D gravity']
# ['37 Earth Sciences', '3706 Geophysics', '370602 Electrical And Electromanetic Methods In Geophysics', 'Magnetotelluric', 'Magnetotelluric_1D']
# ['37 Earth Sciences', '3707 Hydrology', '370703 Groundwater Hydrology', 'Pumping Test']
# ['37 Earth Sciences', '3706 Geophysics', '370609 Seismology And Seismic Exploration', 'Fast Marching Method']
# ['37 Earth Sciences', '3706 Geophysics', '370606 Gravimetrics', '3D gravity']
# ['37 Earth Sciences', '3706 Geophysics', '370602 Electrical And Electromanetic Methods In Geophysics', 'Magnetotelluric', 'Magnetotelluric_1D']
# ['37 Earth Sciences', '3707 Hydrology', '370703 Groundwater Hydrology', 'Pumping Test']
# ['49', '4905', '490501', 'curve fitting']
# ['37 Earth Sciences', '3706 Geophysics', '370609 Seismology And Seismic Exploration', 'Fast Marching Method']
# ['37 Earth Sciences', '3706 Geophysics', '370606 Gravimetrics', '3D gravity']
# ['37 Earth Sciences', '3706 Geophysics', '370602 Electrical And Electromanetic Methods In Geophysics', 'Magnetotelluric', 'Magnetotelluric_1D']
# ['37 Earth Sciences', '3707 Hydrology', '370703 Groundwater Hydrology', 'Pumping Test']
# ['49', '4905', '490501', 'curve fitting']
# ['37 Earth Sciences', '3707 Hydrology', '370703 Groundwater Hydrology', 'Slug Test']
# ['37 Earth Sciences', '3706 Geophysics', '370609 Seismology And Seismic Exploration', 'Fast Marching Method']
# ['37 Earth Sciences', '3706 Geophysics', '370606 Gravimetrics', '3D gravity']
# ['37 Earth Sciences', '3706 Geophysics', '370602 Electrical And Electromanetic Methods In Geophysics', 'Magnetotelluric', 'Magnetotelluric_1D']
# ['37 Earth Sciences', '3707 Hydrology', '370703 Groundwater Hydrology', 'Pumping Test']
# ['49', '4905', '490501', 'curve fitting']
# ['37 Earth Sciences', '3707 Hydrology', '370703 Groundwater Hydrology', 'Slug Test']
# ['37 Earth Sciences', '3706 Geophysics', '370609 Seismology And Seismic Exploration', 'Xray Tracer']
# Example Tree Path:  -> fmm_tomography_gaussian_prior_scipy_opt.py
#
# Example Tree Path:  -> fmm_tomography_simple_newton.py
#
# Example Tree Path:  -> gravity_density_scipy_opt.py
#
# Example Tree Path:  -> pygimli_ert_lib.py
#
# Example Tree Path:  -> pygimli_ert_rect_gauss_newton.py
#
# Example Tree Path:  -> pygimli_ert_rect_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> pygimli_ert_rect_inbuilt_invert.py
#
# Example Tree Path:  -> pygimli_ert_rect_scipy_min.py
#
# Example Tree Path:  -> pygimli_ert_toy_emcee.py
#
# Example Tree Path:  -> pygimli_ert_toy_emcee_parallel.py
#
# Example Tree Path:  -> pygimli_ert_tri_gauss_newton.py
#
# Example Tree Path:  -> pygimli_ert_tri_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> pygimli_ert_tri_inbuilt_invert.py
#
# Example Tree Path:  -> pygimli_ert_tri_scipy_min.py
#
# Example Tree Path:  -> pygimli_ert_tri_torch_optim.py
#
# Example Tree Path:  -> pygimli_ert_lib.py
#
# Example Tree Path:  -> pygimli_ert_rect_emcee.py
#
# Example Tree Path:  -> pygimli_ert_rect_newton_opt.py
#
# Example Tree Path:  -> pygimli_ert_rect_scipy_opt.py
#
# Example Tree Path:  -> pygimli_ert_tri_newton_opt.py
#
# Example Tree Path:  -> simpeg_gravity_gauss_newton.py
#
# Example Tree Path:  -> simpeg_gravity_inbuilt.py
#
# Example Tree Path:  -> simpeg_gravity_lib.py
#
# Example Tree Path:  -> simpeg_gravity_scipy_opt.py
#
# Example Tree Path:  -> xray_tomography_linear_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> fmm_tomography_gaussian_prior_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> fmm_tomography_simple_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> linear_regression_emcee_sampler.py
#
# Example Tree Path:  -> Parameter Estimation -> emcee_parallel_bad_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> emcee_parallel_good_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_rect_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_rect_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_rect_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_rect_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_toy_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_toy_emcee_parallel.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_tri_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_tri_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_tri_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_tri_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_tri_torch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> pygimli_ert_rect_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> simpeg_gravity_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> simpeg_gravity_inbuilt.py
#
# Example Tree Path:  -> Parameter Estimation -> simpeg_gravity_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> simpeg_gravity_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> xray_tomography_linear_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> gravity_density_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_rect_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_rect_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_tri_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> fmm_tomography_gaussian_prior_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> fmm_tomography_simple_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> gravity_density_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> linear_regression_emcee_sampler.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> linear_regression_linear_system_general.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> linear_regression_linear_system_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> linear_regression_linear_system_general-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> linear_regression_linear_system_solver-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> emcee_parallel_bad_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> emcee_parallel_good_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_rect_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_rect_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_rect_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_rect_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_toy_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_toy_emcee_parallel.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_tri_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_tri_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_tri_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_tri_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_tri_torch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_rect_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_rect_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_rect_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> pygimli_ert_tri_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> simpeg_gravity_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> simpeg_gravity_inbuilt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> simpeg_gravity_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> simpeg_gravity_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> xray_tomography_linear_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_optimizer_lstsq.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_optimizer_minimize.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_pytorch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_optimizer_lstsq.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_optimizer_minimize.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_pytorch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_optimizer_lstsq.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_optimizer_minimize.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_pytorch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> fmm_tomography_gaussian_prior_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> fmm_tomography_simple_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> gravity_density_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_emcee_sampler.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_linear_system_general.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_linear_system_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_optimizer_lstsq.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_optimizer_minimize.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_pytorch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_linear_system_general-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> linear_regression_linear_system_solver-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> emcee_parallel_bad_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> emcee_parallel_good_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_rect_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_rect_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_rect_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_rect_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_toy_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_toy_emcee_parallel.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_tri_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_tri_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_tri_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_tri_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_tri_torch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_rect_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_rect_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_rect_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pygimli_ert_tri_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> simpeg_gravity_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> simpeg_gravity_inbuilt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> simpeg_gravity_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> simpeg_gravity_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> xray_tomography_linear_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> gravity_density_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> gravity_density_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> gravity_density_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> gravity_density_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> fmm_tomography_gaussian_prior_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> fmm_tomography_simple_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> gravity_density_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> gravity_density_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> linear_regression_emcee_sampler.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> linear_regression_linear_system_general.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> linear_regression_linear_system_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> linear_regression_optimizer_lstsq.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> linear_regression_optimizer_minimize.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> linear_regression_pytorch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> linear_regression_linear_system_general-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> linear_regression_linear_system_solver-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> emcee_parallel_bad_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> emcee_parallel_good_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_rect_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_rect_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_rect_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_rect_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_toy_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_toy_emcee_parallel.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_tri_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_tri_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_tri_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_tri_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_tri_torch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_rect_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_rect_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_rect_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> pygimli_ert_tri_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> simpeg_gravity_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> simpeg_gravity_inbuilt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> simpeg_gravity_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> simpeg_gravity_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> xray_tomography_linear_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> fmm_tomography_gaussian_prior_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> fmm_tomography_simple_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> gravity_density_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> gravity_density_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> linear_regression_emcee_sampler.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> linear_regression_linear_system_general.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> linear_regression_linear_system_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> linear_regression_optimizer_lstsq.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> linear_regression_optimizer_minimize.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> linear_regression_pytorch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> linear_regression_linear_system_general-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> linear_regression_linear_system_solver-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> emcee_parallel_bad_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> emcee_parallel_good_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_rect_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_rect_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_rect_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_rect_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_toy_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_toy_emcee_parallel.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_tri_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_tri_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_tri_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_tri_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_tri_torch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_rect_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_rect_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_rect_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> pygimli_ert_tri_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> simpeg_gravity_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> simpeg_gravity_inbuilt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> simpeg_gravity_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> simpeg_gravity_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> InLab -> Simple Newton Step -> xray_tomography_linear_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> fmm_tomography_gaussian_prior_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> fmm_tomography_simple_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> gravity_density_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> gravity_density_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> linear_regression_emcee_sampler.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> linear_regression_linear_system_general.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> linear_regression_linear_system_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> linear_regression_optimizer_lstsq.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> linear_regression_optimizer_minimize.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> linear_regression_pytorch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> linear_regression_linear_system_general-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> linear_regression_linear_system_solver-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> emcee_parallel_bad_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> emcee_parallel_good_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_rect_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_rect_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_rect_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_rect_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_toy_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_toy_emcee_parallel.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_tri_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_tri_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_tri_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_tri_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_tri_torch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_rect_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_rect_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_rect_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> pygimli_ert_tri_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> simpeg_gravity_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> simpeg_gravity_inbuilt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> simpeg_gravity_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> simpeg_gravity_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> xray_tomography_linear_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> fmm_tomography_gaussian_prior_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> fmm_tomography_simple_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> gravity_density_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> gravity_density_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> linear_regression_emcee_sampler.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> linear_regression_linear_system_general.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> linear_regression_linear_system_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> linear_regression_optimizer_lstsq.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> linear_regression_optimizer_minimize.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> linear_regression_pytorch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> linear_regression_linear_system_general-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> linear_regression_linear_system_solver-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> emcee_parallel_bad_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> emcee_parallel_good_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_rect_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_rect_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_rect_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_rect_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_toy_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_toy_emcee_parallel.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_tri_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_tri_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_tri_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_tri_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_tri_torch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_rect_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_rect_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_rect_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> pygimli_ert_tri_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> simpeg_gravity_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> simpeg_gravity_inbuilt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> simpeg_gravity_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> simpeg_gravity_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adadelta -> xray_tomography_linear_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> fmm_tomography_gaussian_prior_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> fmm_tomography_simple_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> gravity_density_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> gravity_density_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> linear_regression_emcee_sampler.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> linear_regression_linear_system_general.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> linear_regression_linear_system_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> linear_regression_optimizer_lstsq.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> linear_regression_optimizer_minimize.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> linear_regression_pytorch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> linear_regression_linear_system_general-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> linear_regression_linear_system_solver-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> emcee_parallel_bad_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> emcee_parallel_good_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_rect_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_rect_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_rect_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_rect_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_toy_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_toy_emcee_parallel.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_tri_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_tri_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_tri_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_tri_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_tri_torch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_rect_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_rect_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_rect_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> pygimli_ert_tri_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> simpeg_gravity_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> simpeg_gravity_inbuilt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> simpeg_gravity_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> simpeg_gravity_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adagrad -> xray_tomography_linear_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> fmm_tomography_gaussian_prior_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> fmm_tomography_simple_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> gravity_density_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> gravity_density_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> linear_regression_emcee_sampler.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> linear_regression_linear_system_general.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> linear_regression_linear_system_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> linear_regression_optimizer_lstsq.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> linear_regression_optimizer_minimize.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> linear_regression_pytorch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> linear_regression_linear_system_general-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> linear_regression_linear_system_solver-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> emcee_parallel_bad_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> emcee_parallel_good_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_rect_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_rect_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_rect_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_rect_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_toy_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_toy_emcee_parallel.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_tri_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_tri_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_tri_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_tri_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_tri_torch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_rect_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_rect_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_rect_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> pygimli_ert_tri_newton_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> simpeg_gravity_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> simpeg_gravity_inbuilt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> simpeg_gravity_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> simpeg_gravity_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> Adam -> xray_tomography_linear_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> fmm_tomography_gaussian_prior_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> fmm_tomography_simple_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> gravity_density_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> gravity_density_scipy_opt.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> linear_regression_emcee_sampler.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> linear_regression_linear_system_general.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> linear_regression_linear_system_solver.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> linear_regression_optimizer_lstsq.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> linear_regression_optimizer_minimize.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> linear_regression_pytorch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> linear_regression_linear_system_general-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> linear_regression_linear_system_solver-checkpoint.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> emcee_parallel_bad_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> emcee_parallel_good_practice.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_rect_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_rect_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_rect_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_rect_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_toy_emcee.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_toy_emcee_parallel.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_tri_gauss_newton.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_tri_gauss_newton_armijo_linesearch.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_tri_inbuilt_invert.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_tri_scipy_min.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_tri_torch_optim.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_lib.py
#
# Example Tree Path:  -> Parameter Estimation -> Optimization -> Non-linear -> pytorch.optim -> AdamW -> pygimli_ert_rect_emcee.py
#
# ...
# yields a linear operation: d = Gm,
# where: d refers to data observations (y_1, y_2, ..., y_N).T
#        G refers to basis matrix: ( (1, x_1, x_1^2, x_1^3)
#                                    (1, x_2, x_2^2, x_2^3)
#                                    ...
#                                    (1, x_N, x_N^2, x_N^3) )
#        m refers to the unknown model parameters (m_0, m_1, m_2, m_3)
#
# Note that G matrix is here equivalent to the Jacobian as it entries G(i,j) are the
# first derivative of the i-th datum d(i) with respect to the j-th model parameter m(j).
# We here refer to the function that calculates the G matrix given a set of model
# parameters as the basis function.
#
# To take uncertainty into account, we need an extra data covariance matrix C_d having
# the shape (N,N), where N is the number of data points. Then the formula we try to solve
# is no longer Gm = d, but this instead: (G.T C_d^(-1) G) m = G.T C_d^(-1) d
#
#     Example: linear_regression_linear_system_solver-checkpoint.py (cofi-examples/examples\linear_regression\.ipynb_checkpoints\linear_regression_linear_system_solver-checkpoint.py)
#       Description: Polynomial Linear regression solved by linear system solver
#
# This file sets up an example from setting up problem to running the inversion:
# - For the problem: polynomial linear regression,
# - Using the tool: linear system solver (scipy.linalg.lstsq)
#
# The function we are going to fit is: y = -6 - 5x + 2x^2 + x^3
#
# We may also write the polynomial curves in this form: y = sum(m_n * x^n), n=0,1,2,3,
# where: m_n, n=0,1,2,3 are the model coefficients.
#
# If we consider N data points and M=3 model parameters, then N equations like above
# yields a linear operation: d = Gm,
# where: d refers to data observations (y_1, y_2, ..., y_N).T
#        G refers to basis matrix: ( (1, x_1, x_1^2, x_1^3)
#                                    (1, x_2, x_2^2, x_2^3)
#                                    ...
#                                    (1, x_N, x_N^2, x_N^3) )
#        m refers to the unknown model parameters (m_0, m_1, m_2, m_3)
#
# Note that G matrix is here equivalent to the Jacobian as it entries G(i,j) are the
# first derivative of the i-th datum d(i) with respect to the j-th model parameter m(j).
# We here refer to the function that calculates the G matrix given a set of model
# parameters as the basis function.
#
#     Example: pygimli_ert_lib.py (cofi-examples/examples\pygimli_ert\pygimli_ert_lib.py)
#       Description: Wrappers around PyGIMLi library for ERT problem
#
# The file name should end with "_lib.py", otherwise our bot may fail when generating
# scripts for Sphinx Gallery. Furthermore, we recommend the file name to start with your
# forward problem name, to align well with the naming of Jupyter notebook.
#     Example: pygimli_ert_rect_gauss_newton.py (cofi-examples/examples\pygimli_ert\pygimli_ert_rect_gauss_newton.py)
#       Description:
#     Example: pygimli_ert_rect_gauss_newton_armijo_linesearch.py (cofi-examples/examples\pygimli_ert\pygimli_ert_rect_gauss_newton_armijo_linesearch.py)
#       Description:
#     Example: pygimli_ert_rect_inbuilt_invert.py (cofi-examples/examples\pygimli_ert\pygimli_ert_rect_inbuilt_invert.py)
#       Description:
#     Example: pygimli_ert_rect_scipy_min.py (cofi-examples/examples\pygimli_ert\pygimli_ert_rect_scipy_min.py)
#       Description:
#     Example: pygimli_ert_toy_emcee.py (cofi-examples/examples\pygimli_ert\pygimli_ert_toy_emcee.py)
#       Description:
#     Example: pygimli_ert_toy_emcee_parallel.py (cofi-examples/examples\pygimli_ert\pygimli_ert_toy_emcee_parallel.py)
#       Description:
#     Example: pygimli_ert_tri_gauss_newton.py (cofi-examples/examples\pygimli_ert\pygimli_ert_tri_gauss_newton.py)
#       Description:
#     Example: pygimli_ert_tri_gauss_newton_armijo_linesearch.py (cofi-examples/examples\pygimli_ert\pygimli_ert_tri_gauss_newton_armijo_linesearch.py)
#       Description:
#     Example: pygimli_ert_tri_inbuilt_invert.py (cofi-examples/examples\pygimli_ert\pygimli_ert_tri_inbuilt_invert.py)
#       Description:
#     Example: pygimli_ert_tri_scipy_min.py (cofi-examples/examples\pygimli_ert\pygimli_ert_tri_scipy_min.py)
#       Description:
#     Example: pygimli_ert_tri_torch_optim.py (cofi-examples/examples\pygimli_ert\pygimli_ert_tri_torch_optim.py)
#       Description:
#     Example: pygimli_ert_lib.py (cofi-examples/examples\pygimli_ert\archived\pygimli_ert_lib.py)
#       Description: Wrappers around PyGIMLi library for ERT problem
#
# The file name should end with "_lib.py", otherwise our bot may fail when generating
# scripts for Sphinx Gallery. Furthermore, we recommend the file name to start with your
# forward problem name, to align well with the naming of Jupyter notebook.
#     Example: pygimli_ert_rect_newton_opt.py (cofi-examples/examples\pygimli_ert\archived\pygimli_ert_rect_newton_opt.py)
#       Description: Eletrical Resistivity Tomography Inversion with PyGIMLi + CoFI
#
# This script runs:
# - ERT problem (rectangular mesh) defined with PyGIMLi, and
# - Newton's optimization method with CoFI
#
#
# To run this script, refer to the following examples:
#
# - `python pygimli_ert_rect_newton_opt.py` for a simple run, with all the figures saved to
#   current directory by default
#
# - `python pygimli_ert_rect_newton_opt.py -o figs` for the same run as above, with all the
#   figures saved to subfolder `figs`
#
# - `python pygimli_ert_rect_newton_opt.py -h` to see all available options
#     Example: pygimli_ert_rect_scipy_opt.py (cofi-examples/examples\pygimli_ert\archived\pygimli_ert_rect_scipy_opt.py)
#       Description: Eletrical Resistivity Tomography Inversion with PyGIMLi + CoFI
#
# This script runs:
# - ERT problem (rectangular mesh) defined with PyGIMLi, and
# - Scipy's optimization with CoFI
#
#
# To run this script, refer to the following examples:
#
# - `python pygimli_ert_rect_scipy_opt.py` for a simple run, with all the figures saved to
#   current directory by default
#
# - `python pygimli_ert_rect_scipy_opt.py -o figs` for the same run as above, with all the
#   figures saved to subfolder `figs`
#
# - `python pygimli_ert_rect_scipy_opt.py -h` to see all available options
#     Example: pygimli_ert_tri_newton_opt.py (cofi-examples/examples\pygimli_ert\archived\pygimli_ert_tri_newton_opt.py)
#       Description: Eletrical Resistivity Tomography Inversion with PyGIMLi + CoFI
#
# This script runs:
# - ERT problem (triangular mesh) defined with PyGIMLi, and
# - Newton's optimization method with CoFI
#
#
# To run this script, refer to the following examples:
#
# - `python pygimli_ert_tri_newton_opt.py` for a simple run, with all the figures saved to
#   current directory by default
#
# - `python pygimli_ert_tri_newton_opt.py -o figs` for the same run as above, with all the
#   figures saved to subfolder `figs`
#
# - `python pygimli_ert_tri_newton_opt.py -h` to see all available options
#     Example: simpeg_gravity_gauss_newton.py (cofi-examples/examples\simpeg_gravity\tmp\simpeg_gravity_gauss_newton.py)
#       Description: 2D Gravity Inversion
#
# Gravity inversion using the SimPEG kernels.
#     Example: simpeg_gravity_inbuilt.py (cofi-examples/examples\simpeg_gravity\tmp\simpeg_gravity_inbuilt.py)
#       Description: 2D Gravity Inversion
#
# Gravity inversion using the SimPEG kernels.
#     Example: simpeg_gravity_lib.py (cofi-examples/examples\simpeg_gravity\tmp\simpeg_gravity_lib.py)
#       Description: Template library file(s)
#
# Please put all the library code that will be needed in the notebook in this file.
#
# This file is optional. You can safely delete it if not needed.
#
# The file name should end with "_lib.py", otherwise our bot may fail when generating
# scripts for Sphinx Gallery. Furthermore, we recommend the file name to start with your
# forward problem name, to align well with the naming of Jupyter notebook.
#     Example: simpeg_gravity_scipy_opt.py (cofi-examples/examples\simpeg_gravity\tmp\simpeg_gravity_scipy_opt.py)
#       Description: 2D Gravity Inversion
#
# Gravity inversion using the SimPEG kernels.
#     Example: xray_tomography_linear_solver.py (cofi-examples/examples\xray_tomography\xray_tomography_linear_solver.py)
#       Description: Xray tomography problem solved with CoFI linear system solver,
# with data uncertainty and regularization taken into account.
#   Example: fmm_tomography_gaussian_prior_scipy_opt.py (cofi-examples/examples\fmm_tomography\fmm_tomography_gaussian_prior_scipy_opt.py)
#     Description: Seismic waveform inference with Fast Marching and CoFI
#
# Based on original scripts by Andrew Valentine & Malcolm Sambridge -
# Research Schoole of Earth Sciences, The Australian National University
# Last updated July 2022
#   Example: fmm_tomography_simple_newton.py (cofi-examples/examples\fmm_tomography\fmm_tomography_simple_newton.py)
#     Description: Seismic waveform inference with Fast Marching and CoFI
#
# Based on original scripts by Andrew Valentine & Malcolm Sambridge -
# Research Schoole of Earth Sciences, The Australian National University
# Last updated July 2022
#   Example: gravity_density_scipy_opt.py (cofi-examples/examples\gravity\archived\gravity_density_scipy_opt.py)
#     Description: Gravity Inversion Problem with CoFI
#
# This script runs:
# - Inversion on gravity density model, and
# - Scipy's optimization with CoFI
#
#
# To run this script, refer to the following examples:
#
# - `python gravity_density_scipy_opt.py` for a simple run, with all the figures saved to
#   current directory by default
#
# - `python gravity_density_scipy_opt.py -o figs` for the same run as above, with all the
#   figures saved to subfolder `figs`
#
# - `python gravity_density_scipy_opt.py -h` to see all available options
#   Example: pygimli_ert_lib.py (cofi-examples/examples\pygimli_ert\pygimli_ert_lib.py)
#     Description: Wrappers around PyGIMLi library for ERT problem
#
# The file name should end with "_lib.py", otherwise our bot may fail when generating
# scripts for Sphinx Gallery. Furthermore, we recommend the file name to start with your
# forward problem name, to align well with the naming of Jupyter notebook.
#   Example: pygimli_ert_rect_gauss_newton.py (cofi-examples/examples\pygimli_ert\pygimli_ert_rect_gauss_newton.py)
#     Description:
#   Example: pygimli_ert_rect_gauss_newton_armijo_linesearch.py (cofi-examples/examples\pygimli_ert\pygimli_ert_rect_gauss_newton_armijo_linesearch.py)
#     Description:
#   Example: pygimli_ert_rect_inbuilt_invert.py (cofi-examples/examples\pygimli_ert\pygimli_ert_rect_inbuilt_invert.py)
#     Description:
#   Example: pygimli_ert_rect_scipy_min.py (cofi-examples/examples\pygimli_ert\pygimli_ert_rect_scipy_min.py)
#     Description:
#   Example: pygimli_ert_toy_emcee.py (cofi-examples/examples\pygimli_ert\pygimli_ert_toy_emcee.py)
#     Description:
#   Example: pygimli_ert_toy_emcee_parallel.py (cofi-examples/examples\pygimli_ert\pygimli_ert_toy_emcee_parallel.py)
#     Description:
#   Example: pygimli_ert_tri_gauss_newton.py (cofi-examples/examples\pygimli_ert\pygimli_ert_tri_gauss_newton.py)
#     Description:
#   Example: pygimli_ert_tri_gauss_newton_armijo_linesearch.py (cofi-examples/examples\pygimli_ert\pygimli_ert_tri_gauss_newton_armijo_linesearch.py)
#     Description:
#   Example: pygimli_ert_tri_inbuilt_invert.py (cofi-examples/examples\pygimli_ert\pygimli_ert_tri_inbuilt_invert.py)
#     Description:
#   Example: pygimli_ert_tri_scipy_min.py (cofi-examples/examples\pygimli_ert\pygimli_ert_tri_scipy_min.py)
#     Description:
#   Example: pygimli_ert_tri_torch_optim.py (cofi-examples/examples\pygimli_ert\pygimli_ert_tri_torch_optim.py)
#     Description:
#   Example: pygimli_ert_lib.py (cofi-examples/examples\pygimli_ert\archived\pygimli_ert_lib.py)
#     Description: Wrappers around PyGIMLi library for ERT problem
#
# The file name should end with "_lib.py", otherwise our bot may fail when generating
# scripts for Sphinx Gallery. Furthermore, we recommend the file name to start with your
# forward problem name, to align well with the naming of Jupyter notebook.
#   Example: pygimli_ert_rect_emcee.py (cofi-examples/examples\pygimli_ert\archived\pygimli_ert_rect_emcee.py)
#     Description: Eletrical Resistivity Tomography Inversion with PyGIMLi + CoFI
#
# This script runs:
# - ERT problem (rectangular mesh) defined with PyGIMLi, and
# - Bayesian sampling using emcee with CoFI
#
#
# To run this script, refer to the following examples:
#
# - `python pygimli_ert_rect_emcee.py` for a simple run, with all the figures saved to
#   current directory by default
#
# - `python pygimli_ert_rect_emcee.py -o figs` for the same run as above, with all the
#   figures saved to subfolder `figs`
#
# - `python pygimli_ert_rect_emcee.py -h` to see all available options
#   Example: pygimli_ert_rect_newton_opt.py (cofi-examples/examples\pygimli_ert\archived\pygimli_ert_rect_newton_opt.py)
#     Description: Eletrical Resistivity Tomography Inversion with PyGIMLi + CoFI
#
# This script runs:
# - ERT problem (rectangular mesh) defined with PyGIMLi, and
# - Newton's optimization method with CoFI
#
#
# To run this script, refer to the following examples:
#
# - `python pygimli_ert_rect_newton_opt.py` for a simple run, with all the figures saved to
#   current directory by default
#
# - `python pygimli_ert_rect_newton_opt.py -o figs` for the same run as above, with all the
#   figures saved to subfolder `figs`
#
# - `python pygimli_ert_rect_newton_opt.py -h` to see all available options
#   Example: pygimli_ert_rect_scipy_opt.py (cofi-examples/examples\pygimli_ert\archived\pygimli_ert_rect_scipy_opt.py)
#     Description: Eletrical Resistivity Tomography Inversion with PyGIMLi + CoFI
#
# This script runs:
# - ERT problem (rectangular mesh) defined with PyGIMLi, and
# - Scipy's optimization with CoFI
#
#
# To run this script, refer to the following examples:
#
# - `python pygimli_ert_rect_scipy_opt.py` for a simple run, with all the figures saved to
#   current directory by default
#
# - `python pygimli_ert_rect_scipy_opt.py -o figs` for the same run as above, with all the
#   figures saved to subfolder `figs`
#
# - `python pygimli_ert_rect_scipy_opt.py -h` to see all available options
#   Example: pygimli_ert_tri_newton_opt.py (cofi-examples/examples\pygimli_ert\archived\pygimli_ert_tri_newton_opt.py)
#     Description: Eletrical Resistivity Tomography Inversion with PyGIMLi + CoFI
#
# This script runs:
# - ERT problem (triangular mesh) defined with PyGIMLi, and
# - Newton's optimization method with CoFI
#
#
# To run this script, refer to the following examples:
#
# - `python pygimli_ert_tri_newton_opt.py` for a simple run, with all the figures saved to
#   current directory by default
#
# - `python pygimli_ert_tri_newton_opt.py -o figs` for the same run as above, with all the
#   figures saved to subfolder `figs`
#
# - `python pygimli_ert_tri_newton_opt.py -h` to see all available options
#   Example: simpeg_gravity_gauss_newton.py (cofi-examples/examples\simpeg_gravity\tmp\simpeg_gravity_gauss_newton.py)
#     Description: 2D Gravity Inversion
#
# Gravity inversion using the SimPEG kernels.
#   Example: simpeg_gravity_inbuilt.py (cofi-examples/examples\simpeg_gravity\tmp\simpeg_gravity_inbuilt.py)
#     Description: 2D Gravity Inversion
#
# Gravity inversion using the SimPEG kernels.
#   Example: simpeg_gravity_lib.py (cofi-examples/examples\simpeg_gravity\tmp\simpeg_gravity_lib.py)
#     Description: Template library file(s)
#
# Please put all the library code that will be needed in the notebook in this file.
#
# This file is optional. You can safely delete it if not needed.
#
# The file name should end with "_lib.py", otherwise our bot may fail when generating
# scripts for Sphinx Gallery. Furthermore, we recommend the file name to start with your
# forward problem name, to align well with the naming of Jupyter notebook.
#   Example: simpeg_gravity_scipy_opt.py (cofi-examples/examples\simpeg_gravity\tmp\simpeg_gravity_scipy_opt.py)
#     Description: 2D Gravity Inversion
#
# Gravity inversion using the SimPEG kernels.
#   Example: xray_tomography_linear_solver.py (cofi-examples/examples\xray_tomography\xray_tomography_linear_solver.py)
#     Description: Xray tomography problem solved with CoFI linear system solver,
# with data uncertainty and regularization taken into account.
